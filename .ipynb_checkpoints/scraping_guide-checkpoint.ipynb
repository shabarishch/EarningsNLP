# %% [markdown]
# # Earnings Call Transcript Gathering

# %% [markdown]
# ## Step-1 API Key
#
# Sign in to https://rapidapi.com/apidojo/api/seeking-alpha and get an API key. You can find it with the label 'X-RapidAPI-Key'

# %% [markdown]
# ## Step-2 List of Transcripts
#
# Get list of available transcripts for a given company with the following code.

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40"}

headers = {
	"X-RapidAPI-Key": "", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list = response.json()

# %%
transcripts_list
# Out:
# {'data': [{'id': '4676748',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2024-03-07T15:04:09-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Morgan Stanley Technology, Media and Telecom Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4676748-microsoft-corporation-msft-morgan-stanley-technology-media-and-telecom-conference-transcript'}},
#   {'id': '4666217',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2024-01-30T21:32:11-05:00',
#     'isLockedPro': False,
#     'commentCount': 2,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Q2 2024 Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4666217-microsoft-corporation-msft-q2-2024-earnings-call-transcript'}},
#   {'id': '4666183',
#    'type': 'earningsSlide',
#    'attributes': {'publishOn': '2024-01-30T18:34:39-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation 2024 Q2 - Results - Earnings Call Presentation',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4666183-microsoft-corporation-2024-q2-results-earnings-call-presentation'}},
#   {'id': '4656730',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-12-07T22:30:18-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Presents at Barclays Global Technology Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4656730-microsoft-corporation-msft-presents-barclays-global-technology-conference-transcript'}},
#   {'id': '4655000',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-11-29T17:22:06-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) UBS Global Technology Conference',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4655000-microsoft-corporation-msft-ubs-global-technology-conference'}},
#   {'id': '4654726',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-11-28T19:07:03-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Presents at Wells Fargo TMT Summit Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4654726-microsoft-corporation-msft-presents-wells-fargo-tmt-summit-conference-transcript'}},
#   {'id': '4643129',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-10-24T22:14:03-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Q1 2024 Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4643129-microsoft-corporation-msft-q1-2024-earnings-call-transcript'}},
#   {'id': '4633767',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-09-07T14:43:08-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Citi 2023 Global Technology Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4633767-microsoft-corporation-msft-citi-2023-global-technology-conference-transcript'}},
#   {'id': '4633766',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-09-07T14:35:54-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Goldman Sachs 2023 Communacopia + Technology Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4633766-microsoft-corporation-msft-goldman-sachs-2023-communacopia-technology-conference-transcript'}},
#   {'id': '4632174',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-08-30T22:25:32-04:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': "Microsoft Corporation (MSFT) Deutsche Bank's 2023 Technology Conference - (Transcript)",
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4632174-microsoft-corporation-msft-deutsche-banks-2023-technology-conference-transcript'}},
#   {'id': '4619767',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-07-25T21:56:09-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Q4 2023 Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4619767-microsoft-corporation-msft-q4-2023-earnings-call-transcript'}},
#   {'id': '4610067',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-06-07T13:50:19-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Management Presents at Bank of America Global Technology Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4610067-microsoft-corporation-msft-management-presents-bank-of-america-global-technology-conference'}},
#   {'id': '4608583',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-05-31T15:47:07-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Jefferies Software Conference 2023 (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4608583-microsoft-corporation-msft-jefferies-software-conference-2023-transcript'}},
#   {'id': '4606863',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-05-23T16:50:24-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) 51st Annual JP Morgan Global Technology, Media and Communications Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4606863-microsoft-corporation-msft-51st-annual-jp-morgan-global-technology-media-and-communications'}},
#   {'id': '4596556',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023
05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Management Presents at Morgan Stanley Technology, Media and Telecom Conference 2022 (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4493767-microsoft-corporation-msft-management-presents-morgan-stanley-technology-media-and-telecom'}},
#   {'id': '4481661',
#    'type': 'earningsSlide',
#    'attributes': {'publishOn': '2022-01-26T03:37:36-05:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation 2022 Q2 - Results - Earnings Call Presentation',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4481661-microsoft-corporation-2022-q2-results-earnings-call-presentation'}},
#   {'id': '4481617',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2022-01-25T20:51:02-05:00',
#     'isLockedPro': False,
#     'commentCount': 3,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': "Microsoft Corporation's (MSFT) CEO Satya Nadella on Q2 2022 Results - Earnings Call Transcript",
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4481617-microsoft-corporations-msft-ceo-satya-nadella-on-q2-2022-results-earnings-call-transcript'}},
#   {'id': '4480183',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2022-01-18T14:30:02-05:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': "Microsoft Corporation's (MSFT) CEO Satya Nadella on Microsoft and Activision Blizzard Conference Call (Transcript)",
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4480183-microsoft-corporations-msft-ceo-satya-nadella-on-microsoft-and-activision-blizzard-conference'}},
#   {'id': '4474209',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2021-12-08T19:54:09-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Management Presents at Barclays Global Technology, Media and Telecommunications Conference Call (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4474209-microsoft-corporation-msft-management-presents-barclays-global-technology-media-and'}},
#   {'id': '4474165',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2021-12-08T15:25:07-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Presents at UBS 2021 Global TMT Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4474165-microsoft-corporation-msft-presents-ubs-2021-global-tmt-conference-transcript'}},
#   {'id': '4472847',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2021-12-01T14:45:27-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Presents at Annual Virtual Wells Fargo TMT Summit (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4472847-microsoft-corporation-msft-presents-annual-virtual-wells-fargo-tmt-summit-transcript'}},
#   {'id': '4472640',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2021-11-30T15:23:10-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': "Microsoft Corporation's (MSFT) Management on Credit Suisse Annual Technology Conference - Transcript",
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4472640-microsoft-corporations-msft-management-on-credit-suisse-annual-technology-conference'}},
#   {'id': '4462243',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2021-10-26T21:19:06-04:00',
#     'isLockedPro': False,
#     'commentCount': 3,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) CEO Satya Nadella on Q1 Fiscal 2022 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4462243-microsoft-corporation-msft-ceo-satya-nadella-on-q1-fiscal-2022-results-earnings-call'}}],
#  'included': [{'id': '44211',
#    'type': 'author',
#    'attributes': {'company': None,
#     'slug': 'sa-transcripts',
#     'userId': 101639,
#     'tagId': 96991,
#     'image': {'small': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/small_pic.png',
#      'medium': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/medium_pic.png',
#      'big': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/big_pic.png',
#      'extra_large': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/extra_large_pic.png'},
#     'nick': 'SA Transcripts',
#     'bio': "Seeking Alpha's transcripts team is responsible for the development of all of our transcript-related projects. We currently publish thousands of quarterly earnings calls per quarter on our site and are continuing to grow and expand our coverage. The purpose of this profile is to allow us to share with our readers new transcript-related developments. Thanks, SA Transcripts Team",
#     'deactivated': None,
#     'memberSince': 2007,
#     'isRss': False,
#     'contributorSince': 2013,
#     'followersCount': 145273},
#    'relationships': {'user': {'data': {'id': '101639', 'type': 'user'}}},
#    'links': {'self': '/author/sa-transcripts',
#     'profileUrl': '/author/sa-transcripts',
#     'site': None,
#     'linkedinUrl': None,
#     'twitterUrl': None}},
#   {'id': '575',
#    'type': 'tag',
#    'attributes': {'slug': 'msft', 'name': 'MSFT'},
#    'links': {'self': '/symbol/MSFT'}}],
#  'meta': {'page': {'title': 'Microsoft Corporation (MSFT) Earnings Transcripts',
#    'description': 'All earnings call transcripts on Microsoft Corporation (MSFT) stock. Read or listen to the conference call. Download the investor presentation - earnings call slides.',
#    'listTitle': 'Transcripts',
#    'listDescription': None,
#    'proStatus': 0,
#    'uriImage': 'https://static.seekingalpha.com/assets/og_image_1200-29b2bfe1a595477db6826bd2126c63ac2091efb7ec76347a8e7f81ba17e3de6c.png',
#    'size': 40,
#    'totalPages': 8,
#    'total': 293,
#    'minmaxPublishOn': {'min': 1635297546, 'max': 1709841849}},
#   'mone': {'params': {'pu': ''}}}}

# %% [markdown]
# Note the 'minmaxPublishOn' key in the above response. We shall use it later.

# %%
import pandas as pd


transcripts_list_idtitle = []

for item in transcripts_list['data']:
    transcripts_list_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list_df = pd.DataFrame(transcripts_list_idtitle)

# %%
transcripts_list_df
# Out:
#          id                                              Title
# 0   4676748  Microsoft Corporation (MSFT) Morgan Stanley Te...
# 1   4666217  Microsoft Corporation (MSFT) Q2 2024 Earnings ...
# 2   4666183  Microsoft Corporation 2024 Q2 - Results - Earn...
# 3   4656730  Microsoft Corporation (MSFT) Presents at Barcl...
# 4   4655000  Microsoft Corporation (MSFT) UBS Global Techno...
# 5   4654726  Microsoft Corporation (MSFT) Presents at Wells...
# 6   4643129  Microsoft Corporation (MSFT) Q1 2024 Earnings ...
# 7   4633767  Microsoft Corporation (MSFT) Citi 2023 Global ...
# 8   4633766  Microsoft Corporation (MSFT) Goldman Sachs 202...
# 9   4632174  Microsoft Corporation (MSFT) Deutsche Bank's 2...
# 10  4619767  Microsoft Corporation (MSFT) Q4 2023 Earnings ...
# 11  4610067  Microsoft Corporation (MSFT) Management Presen...
# 12  4608583  Microsoft Corporation (MSFT) Jefferies Softwar...
# 13  4606863  Microsoft Corporation (MSFT) 51st Annual JP Mo...
# 14  4596556  Microsoft Corporation (MSFT) Q3 2023 Earnings ...
# 15  4585447  Microsoft Corporation (MSFT) Presents at Morga...
# 16  4572124  Microsoft Corporation 2023 Q2 - Results - Earn...
# 17  4572123  Microsoft Corporation (MSFT) Q2 2023 Earnings ...
# 18  4563055  Microsoft Corporation (MSFT) Barclays 2022 Glo...
# 19  4562729  Microsoft Corporation (MSFT) UBS 50th Annual G...
# 20  4561183  Microsoft Corporation (MSFT) Management Presen...
# 21  4549108  Microsoft Corporation (MSFT) Q1 2023 Earnings ...
# 22  4549099  Microsoft Corporation 2023 Q1 - Results - Earn...
# 23  4540556  Microsoft Corporation (MSFT) 2022 Goldman Sach...
# 24  4539515  Microsoft Corporation (MSFT) 2022 Citi Global ...
# 25  4538257  Microsoft Corporation (MSFT) Presents at Deuts...
# 26  4526112  Microsoft Corporation 2022 Q4 - Results - Earn...
# 27  4526087  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 28  4516125  Microsoft Corporation's (MSFT) Management Pres...
# 29  4514466  Microsoft Corporation's (MSFT) Management Pres...
# 30  4503841  Microsoft's (MSFT) CEO Satya Nadella on Q3 202...
# 31  4493767  Microsoft Corporation (MSFT) Management Presen...
# 32  4481661  Microsoft Corporation 2022 Q2 - Results - Earn...
# 33  4481617  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 34  4480183  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 35  4474209  Microsoft Corporation (MSFT) Management Presen...
# 36  4474165  Microsoft Corporation (MSFT) Presents at UBS 2...
# 37  4472847  Microsoft Corporation (MSFT) Presents at Annua...
# 38  4472640  Microsoft Corporation's (MSFT) Management on C...
# 39  4462243  Microsoft Corporation (MSFT) CEO Satya Nadella...

# %% [markdown]
# ## Step - 3 Filter Earnings Call Transcripts
#
# As you can see, the API returns many different transcripts. We are only interested in earnings call transcripts. The next step is to filter out these id's.

# %%
transcripts_useful = transcripts_list_df.loc[transcripts_list_df['Title'].str.find('Earnings Call Transcript')>=0]

# %%
transcripts_useful
# Out:
#          id                                              Title
# 1   4666217  Microsoft Corporation (MSFT) Q2 2024 Earnings ...
# 6   4643129  Microsoft Corporation (MSFT) Q1 2024 Earnings ...
# 10  4619767  Microsoft Corporation (MSFT) Q4 2023 Earnings ...
# 14  4596556  Microsoft Corporation (MSFT) Q3 2023 Earnings ...
# 17  4572123  Microsoft Corporation (MSFT) Q2 2023 Earnings ...
# 21  4549108  Microsoft Corporation (MSFT) Q1 2023 Earnings ...
# 27  4526087  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 30  4503841  Microsoft's (MSFT) CEO Satya Nadella on Q3 202...
# 33  4481617  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 39  4462243  Microsoft Corporation (MSFT) CEO Satya Nadella...

# %% [markdown]
# Sometimes even after this filter, there may be unnecessary transcripts in this list (see below for examples)
#
# ### **Figure out a way to get only Earnings Call Transcripts in this list, this has to be done on a stock by stock basis**
#
# Since we only get 500 API calls for free, it is good to not download unnecessary stuff.
#
# Beyond this step, it is assumed that the dataframe transcripts_useful contains only earnings call transcripts

# %% [markdown]
# ## Step 4 - Download and Store Earnings Call Transcript
#
# Before doing this, create a folder with the company's name in the folder containing this jupyter notebook. In this example, I have created a folder with the name "Microsoft".

# %%
import json

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

headers = {
	"X-RapidAPI-Key": "", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

for ind in transcripts_useful.index:
	response = requests.get(url, headers=headers, params={"id": transcripts_useful['id'][ind]} )
	filename = transcripts_useful['Title'][ind]
	f = open(company_name+'/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()

# %% [markdown]
# ## Step 5 - Repeat for older transcripts
#
# Note the 'minmaxPublishOn' key the last time we got transcripts details. When we next get details, we will only get details upto the 'min' value minus 1

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40", "until":'1635297546'}
#Note the new key "until", this denotes the time upto which we need the transcript details

headers = {
	"X-RapidAPI-Key": "", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list2 = response.json()

# %%
transcripts_list2
# Out:
# {'data': [{'id': '4455407',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2021-09-15T14:32:04-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) Presents at Virtual mCloud Connect 2021 Conference (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/
- Results - Earnings Call Presentation',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4341159-microsoft-corporation-2020-q3-results-earnings-call-presentation'}},
#   {'id': '4321809',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2020-02-05T22:43:33-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications, Inc. (NUAN) CEO Mark Benjamin on Q1 2020 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4321809-nuance-communications-inc-nuan-ceo-mark-benjamin-on-q1-2020-results-earnings-call-transcript'}},
#   {'id': '4320005',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2020-01-29T21:38:32-05:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) CEO Satya Nadella on Q2 2020 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4320005-microsoft-corporation-msft-ceo-satya-nadella-on-q2-2020-results-earnings-call-transcript'}},
#   {'id': '4319939',
#    'type': 'earningsSlide',
#    'attributes': {'publishOn': '2020-01-29T16:20:11-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation 2020 Q2 - Results - Earnings Call Presentation',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4319939-microsoft-corporation-2020-q2-results-earnings-call-presentation'}},
#   {'id': '4310584',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2019-12-04T15:41:24-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) 2019 Annual Shareholders Meeting (Transcript)',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4310584-microsoft-corporation-msft-2019-annual-shareholders-meeting-transcript'}},
#   {'id': '4308329',
#    'type': 'earningsSlide',
#    'attributes': {'publishOn': '2019-11-21T12:49:48-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications, Inc. 2019 Q4 - Results - Earnings Call Presentation',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4308329-nuance-communications-inc-2019-q4-results-earnings-call-presentation'}},
#   {'id': '4308156',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2019-11-20T22:45:46-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications, Inc. (NUAN) CEO Mark Benjamin on Q4 2019 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4308156-nuance-communications-inc-nuan-ceo-mark-benjamin-on-q4-2019-results-earnings-call-transcript'}},
#   {'id': '4298421',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2019-10-23T22:19:39-04:00',
#     'isLockedPro': False,
#     'commentCount': 3,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corp. (MSFT) CEO Satya Nadella on Q1 2020 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4298421-microsoft-corp-msft-ceo-satya-nadella-on-q1-2020-results-earnings-call-transcript'}},
#   {'id': '4298328',
#    'type': 'earningsSlide',
#    'attributes': {'publishOn': '2019-10-23T16:19:26-04:00',
#     'isLockedPro': False,
#     'commentCount': 5,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation 2020 Q1 - Results - Earnings Call Presentation',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4298328-microsoft-corporation-2020-q1-results-earnings-call-presentation'}},
#   {'id': '4282953',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2019-08-07T21:37:03-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications, Inc. (NUAN) CEO Mark Benjamin on Q3 2019 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4282953-nuance-communications-inc-nuan-ceo-mark-benjamin-on-q3-2019-results-earnings-call-transcript'}},
#   {'id': '4275911',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2019-07-18T22:27:08-04:00',
#     'isLockedPro': False,
#     'commentCount': 9,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation (MSFT) CEO Satya Nadella on Q4 2019 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4275911-microsoft-corporation-msft-ceo-satya-nadella-on-q4-2019-results-earnings-call-transcript'}}],
#  'included': [{'id': '44211',
#    'type': 'author',
#    'attributes': {'company': None,
#     'slug': 'sa-transcripts',
#     'userId': 101639,
#     'tagId': 96991,
#     'image': {'small': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/small_pic.png',
#      'medium': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/medium_pic.png',
#      'big': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/big_pic.png',
#      'extra_large': 'https://static3.seekingalpha.com/images/users_profile/000/101/639/extra_large_pic.png'},
#     'nick': 'SA Transcripts',
#     'bio': "Seeking Alpha's transcripts team is responsible for the development of all of our transcript-related projects. We currently publish thousands of quarterly earnings calls per quarter on our site and are continuing to grow and expand our coverage. The purpose of this profile is to allow us to share with our readers new transcript-related developments. Thanks, SA Transcripts Team",
#     'deactivated': None,
#     'memberSince': 2007,
#     'isRss': False,
#     'contributorSince': 2013,
#     'followersCount': 145274},
#    'relationships': {'user': {'data': {'id': '101639', 'type': 'user'}}},
#    'links': {'self': '/author/sa-transcripts',
#     'profileUrl': '/author/sa-transcripts',
#     'site': None,
#     'linkedinUrl': None,
#     'twitterUrl': None}},
#   {'id': '575',
#    'type': 'tag',
#    'attributes': {'slug': 'msft', 'name': 'MSFT'},
#    'links': {'self': '/symbol/MSFT'}}],
#  'meta': {'page': {'title': 'Microsoft Corporation (MSFT) Earnings Transcripts',
#    'description': 'All earnings call transcripts on Microsoft Corporation (MSFT) stock. Read or listen to the conference call. Download the investor presentation - earnings call slides.',
#    'listTitle': 'Transcripts',
#    'listDescription': None,
#    'proStatus': 0,
#    'uriImage': 'https://static.seekingalpha.com/assets/og_image_1200-29b2bfe1a595477db6826bd2126c63ac2091efb7ec76347a8e7f81ba17e3de6c.png',
#    'size': 40,
#    'totalPages': 7,
#    'total': 253,
#    'minmaxPublishOn': {'min': 1563503228, 'max': 1631730724}},
#   'mone': {'params': {'pu': ''}}}}

# %%
transcripts_list2_idtitle = []

for item in transcripts_list2['data']:
    transcripts_list2_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list2_df = pd.DataFrame(transcripts_list2_idtitle)

# %%
transcripts_list2_df
# Out:
#          id                                              Title
# 0   4455407  Microsoft Corporation (MSFT) Presents at Virtu...
# 1   4455238  Microsoft Corporation's (MSFT) Management Pres...
# 2   4454344  Microsoft Corporation's (MSFT) Management Pres...
# 3   4441926  Microsoft Corporation 2021 Q4 - Results - Earn...
# 4   4441881  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 5   4433529  Microsoft Corporation (MSFT) Management Presen...
# 6   4431268  Microsoft Corporation's (MSFT) Management Pres...
# 7   4421835  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 8   4421758  Microsoft Corporation 2021 Q3 - Results - Earn...
# 9   4413021  Microsoft Corporation's (MSFT) Management Pres...
# 10  4410681  Microsoft Corporation (MSFT) Presents at Morga...
# 11  4404446  Nuance Communications, Inc.'s (NUAN) CEO Mark ...
# 12  4401205  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 13  4401141  Microsoft Corporation 2021 Q2 - Results - Earn...
# 14  4393917  Microsoft Corporation (MSFT) Presents at Barcl...
# 15  4393714  Microsoft Corporation (MSFT) Management Presen...
# 16  4392585  Microsoft Corporation (MSFT) 2020 Annual Share...
# 17  4392405  Microsoft's (MSFT) Management Presents at Cred...
# 18  4390171  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 19  4388809  Microsoft Corporation (MSFT) Management Presen...
# 20  4381922  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 21  4374539  Microsoft Corp (MSFT) Presents at Deutsche Ban...
# 22  4374297  Microsoft Corporation's (MSFT) Management Pres...
# 23  4370750  Microsoft Corp. (MSFT) Presents at BMO Technol...
# 24  4365022  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 25  4360065  Microsoft Corp. (MSFT) CEO Satya Nadella on Q4...
# 26  4360032  Microsoft Corporation 2020 Q4 - Results - Earn...
# 27  4344465  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 28  4341291  Microsoft Corp (MSFT) CEO Satya Nadella on Q3 ...
# 29  4341159  Microsoft Corporation 2020 Q3 - Results - Earn...
# 30  4321809  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 31  4320005  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 32  4319939  Microsoft Corporation 2020 Q2 - Results - Earn...
# 33  4310584  Microsoft Corporation (MSFT) 2019 Annual Share...
# 34  4308329  Nuance Communications, Inc. 2019 Q4 - Results ...
# 35  4308156  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 36  4298421  Microsoft Corp. (MSFT) CEO Satya Nadella on Q1...
# 37  4298328  Microsoft Corporation 2020 Q1 - Results - Earn...
# 38  4282953  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 39  4275911  Microsoft Corporation (MSFT) CEO Satya Nadella...

# %%
transcripts_useful2 = transcripts_list2_df.loc[transcripts_list2_df['Title'].str.find('Earnings Call Transcript')>=0]

# %%
transcripts_useful2
# Out:
#          id                                              Title
# 4   4441881  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 7   4421835  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 11  4404446  Nuance Communications, Inc.'s (NUAN) CEO Mark ...
# 12  4401205  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 18  4390171  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 20  4381922  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 24  4365022  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 25  4360065  Microsoft Corp. (MSFT) CEO Satya Nadella on Q4...
# 27  4344465  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 28  4341291  Microsoft Corp (MSFT) CEO Satya Nadella on Q3 ...
# 30  4321809  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 31  4320005  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 35  4308156  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 36  4298421  Microsoft Corp. (MSFT) CEO Satya Nadella on Q1...
# 38  4282953  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 39  4275911  Microsoft Corporation (MSFT) CEO Satya Nadella...

# %% [markdown]
# Here you see that the API returns some other company's earnings call transcripts as well. Filter these out.

# %%
transcripts_useful2 = transcripts_useful2.loc[transcripts_list2_df['Title'].str.find('MSFT')>=0]

# %%
transcripts_useful2
# Out:
#          id                                              Title
# 4   4441881  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 7   4421835  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 12  4401205  Microsoft Corporation's (MSFT) CEO Satya Nadel...
# 20  4381922  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 25  4360065  Microsoft Corp. (MSFT) CEO Satya Nadella on Q4...
# 28  4341291  Microsoft Corp (MSFT) CEO Satya Nadella on Q3 ...
# 31  4320005  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 36  4298421  Microsoft Corp. (MSFT) CEO Satya Nadella on Q1...
# 39  4275911  Microsoft Corporation (MSFT) CEO Satya Nadella...

# %%
import json

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

headers = {
	"X-RapidAPI-Key": "", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

for ind in transcripts_useful2.index:
	response = requests.get(url, headers=headers, params={"id": transcripts_useful2['id'][ind]} )
	filename = transcripts_useful2['Title'][ind]
	f = open(company_name+'/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()
