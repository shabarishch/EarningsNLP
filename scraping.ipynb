# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

querystring = {"id":"4341792"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'id': '4341792', 'type': 'fullArticle', 'attributes': {'publishOn': '2020-04-30T21:51:10-04:00', 'isLockedPro': False, 'commentCount': 19, 'gettyImageUrl': None, 'videoPreviewUrl': None, 'themes': {'sa-transcripts': {'id': 96991, 'slug': 'sa-transcripts', 'kind': 'common', 'non_theme': True}, 'aapl': {'id': 146, 'slug': 'aapl', 'kind': 'common', 'non_theme': True}, 'technology': {'id': 17994, 'slug': 'technology', 'kind': 'common', 'path': '/stock-ideas/technology', 'title': 'Tech\xa0', 'non_theme': True}, 'transcripts': {'id': 49, 'slug': 'transcripts', 'kind': 'general', 'path': '/earnings/earnings-call-transcripts', 'title': 'Transcripts'}, 'has-audio': {'id': 586376, 'slug': 'has-audio', 'kind': 'general'}, 'us': {'id': 326, 'slug': 'us', 'kind': 'common', 'non_theme': True}, 'personal-computers': {'id': 18013, 'slug': 'personal-computers', 'kind': 'common', 'non_theme': True}, 'information-technology': {'id': 45, 'slug': 'information-technology', 'kind': 'sector', 'pat
# ...

# %%
response_json = response.json()

# %%
response_json['data'].keys()
# Out:
# dict_keys(['id', 'type', 'attributes', 'relationships', 'links'])

# %%
response_json['data']['attributes']['content']
# Out:
# '<p>Apple Inc. (<span class="ticker-hover-wrapper">NASDAQ:<a href="https://seekingalpha.com/symbol/AAPL" title="Apple Inc.">AAPL</a></span>) Q2 2020 Results Conference Call April 30, 2020 5:00 PM ET</p> <p><strong>Company Participants</strong></p> <p>Tejas Gala - Senior Manager, Corporate Finance and IR</p> <p>Tim Cook - CEO</p> <p>Luca Maestri - CFO</p> <p><strong>Conference Call Participants</strong></p> <p>Shannon Cross - Cross Research</p> <p>Wamsi Mohan - Bank of America</p> <p>Katy Huberty - Morgan Stanley</p> <p>Amit Daryanani - Evercore</p> <p>Jeriel Ong - Deutsche Bank</p> <p>Samik Chatterjee - JP Morgan</p> <p>Chris Caso - Raymond James</p> <p><strong>Operator</strong></p> <p>Good day everyone. Welcome to the Apple Incorporated Second Quarter Fiscal Year 2020 Earnings Conference Call. Today’s call is being recorded.</p> <p>At this time for opening remarks and introductions, I would like to turn the call over to Mr. Tejas Gala, Senior Manager, Corporate Finance and Investor 
# ...

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"aapl","size":"2","number":"1"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())

response_list = response.json()

# %%
response_list.keys()
# Out:
# dict_keys(['data', 'included', 'meta'])

# %%
response_list['data']
# Out:
# [{'id': '4666956',
#   'type': 'transcript',
#   'attributes': {'publishOn': '2024-02-01T20:17:02-05:00',
#    'isLockedPro': False,
#    'commentCount': 18,
#    'gettyImageUrl': None,
#    'videoPreviewUrl': None,
#    'themes': {},
#    'title': 'Apple Inc. (AAPL) Q1 2024 Earnings Call Transcript',
#    'isPaywalled': False},
#   'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#    'sentiments': {'data': []},
#    'primaryTickers': {'data': [{'id': '146', 'type': 'tag'}]},
#    'secondaryTickers': {'data': []},
#    'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#   'links': {'self': '/article/4666956-apple-inc-aapl-q1-2024-earnings-call-transcript'}},
#  {'id': '4646927',
#   'type': 'transcript',
#   'attributes': {'publishOn': '2023-11-02T21:32:21-04:00',
#    'isLockedPro': False,
#    'commentCount': 1,
#    'gettyImageUrl': None,
#    'videoPreviewUrl': None,
#    'themes': {},
# ...

# %%
for item in response_list['data']:
    print(item['id'])
# Out:
# 4666956
# 4646927

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

querystring = {"id":"4666956"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

response_q12024 = response.json()

# %%
response_q12024['data']['attributes']['content']
# Out:
# '<p>Apple Inc. (<span class="ticker-hover-wrapper">NASDAQ:<a href="https://seekingalpha.com/symbol/AAPL" title="Apple Inc.">AAPL</a></span>) Q1 2024 Earnings Conference Call February 1, 2024 5:00 PM ET</p> <p><strong>Company Participants</strong></p> <p>Suhasini Chandramouli - Director of Investor Relations</p> <p>Tim Cook - CEO</p> <p>Luca Maestri - CFO</p> <p><strong>Conference Call Participants</strong></p> <p>Erik Woodring - Morgan Stanley</p> <p>Mike Ng - Goldman Sachs Group</p> <p>Wamsi Mohan - Bank of America</p> <p>Amit Daryanani - Evercore ISI</p> <p>Aaron Rakers - Wells Fargo Securities</p> <p>Krish Sankar - TD Cowen</p> <p>David Vogt - UBS</p> <p>Ben Reitzes - Melius Research</p> <p><strong>Operator</strong></p> <p>Good day, and welcome to the Apple Q1 Fiscal Year 2024 Earnings Conference Call. Today\'s call is being recorded. At this time, for opening remarks and introductions. I would like to turn the call over to Suhasini Chandramouli, Director of Investor Relations. Pl
# ...

# %%
import json
f = open('aapl_2024_q1_transcript.txt', 'w')

json.dump(response_q12024['data']['attributes']['content'], f)

f.close()

# %%
f = open('aapl_2024_q1.txt', 'w')

json.dump(response_q12024, f)

f.close()

# %%
f = open('Apple/aapl_2024_q1.txt')

resp_2024_q1_fromlocaljson = json.load(f)

f.close()

# %%
resp_2024_q1_fromlocaljson['data']['attributes']['content']
# Out:
# '<p>Apple Inc. (<span class="ticker-hover-wrapper">NASDAQ:<a href="https://seekingalpha.com/symbol/AAPL" title="Apple Inc.">AAPL</a></span>) Q1 2024 Earnings Conference Call February 1, 2024 5:00 PM ET</p> <p><strong>Company Participants</strong></p> <p>Suhasini Chandramouli - Director of Investor Relations</p> <p>Tim Cook - CEO</p> <p>Luca Maestri - CFO</p> <p><strong>Conference Call Participants</strong></p> <p>Erik Woodring - Morgan Stanley</p> <p>Mike Ng - Goldman Sachs Group</p> <p>Wamsi Mohan - Bank of America</p> <p>Amit Daryanani - Evercore ISI</p> <p>Aaron Rakers - Wells Fargo Securities</p> <p>Krish Sankar - TD Cowen</p> <p>David Vogt - UBS</p> <p>Ben Reitzes - Melius Research</p> <p><strong>Operator</strong></p> <p>Good day, and welcome to the Apple Q1 Fiscal Year 2024 Earnings Conference Call. Today\'s call is being recorded. At this time, for opening remarks and introductions. I would like to turn the call over to Suhasini Chandramouli, Director of Investor Relations. Pl
# ...

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"goog","size":"5"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())

goog_list = response.json()

# %%
goog_list
# Out:
# {'data': [{'id': '4666190',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2024-01-30T19:16:08-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Alphabet Inc. (GOOG) Q4 2023 Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '544', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4666190-alphabet-inc-goog-q4-2023-earnings-call-transcript'}},
#   {'id': '4656174',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2023-12-05T18:54:08-05:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
# ...

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"goog","size":"40"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())

goog_list2 = response.json()

# %%
goog_list2_titles = []
for item in goog_list2['data']:
    print(item['attributes']['title'])
    goog_list2_titles.append(item['attributes']['title'])
# Out:
# Alphabet Inc. (GOOG) Q4 2023 Earnings Call Transcript
# Alphabet Inc (GOOG) Presents at Scotiabank Inaugural Global Technology Conference (Transcript)
# Alphabet Inc. (GOOG) Q3 2023 Earnings Call Transcript
# Alphabet Inc. (GOOG) Presents at Goldman Sachs Communacopia & Technology Conference (Transcript)
# Alphabet Inc. (GOOG) Q2 2023 Earnings Call Transcript
# Alphabet Inc. (GOOG) SVB MoffettNathanson's Inaugural Technology, Media, and Telecom Conference (Transcript)
# Alphabet Inc. (GOOG) Q1 2023 Earnings Call Transcript
# Alphabet Inc. (GOOG) Morgan Stanley Technology, Media & Telecom Conference (Transcript)
# Alphabet Inc. (GOOG) Q4 2022 Earnings Call Transcript
# Alphabet Inc. (GOOG) Q3 2022 Earnings Call Transcript
# Alphabet (GOOGL) Investor Presentation - Slideshow
# Alphabet Inc. (GOOG) CEO Sundar Pichai on Q2 2022 Results - Earnings Call Transcript
# ...

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"msft","size":"40"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())

msft_list2 = response.json()

# %%
for item in msft_list2['data']:
    print(item['attributes']['title'])
# Out:
# Microsoft Corporation (MSFT) Morgan Stanley Technology, Media and Telecom Conference (Transcript)
# Microsoft Corporation (MSFT) Q2 2024 Earnings Call Transcript
# Microsoft Corporation 2024 Q2 - Results - Earnings Call Presentation
# Microsoft Corporation (MSFT) Presents at Barclays Global Technology Conference (Transcript)
# Microsoft Corporation (MSFT) UBS Global Technology Conference
# Microsoft Corporation (MSFT) Presents at Wells Fargo TMT Summit Conference (Transcript)
# Microsoft Corporation (MSFT) Q1 2024 Earnings Call Transcript
# Microsoft Corporation (MSFT) Citi 2023 Global Technology Conference (Transcript)
# Microsoft Corporation (MSFT) Goldman Sachs 2023 Communacopia + Technology Conference (Transcript)
# Microsoft Corporation (MSFT) Deutsche Bank's 2023 Technology Conference - (Transcript)
# Microsoft Corporation (MSFT) Q4 2023 Earnings Call Transcript
# Microsoft Corporation (MSFT) Management Presents at Bank of America Global Technology Conference (Transcript)
# ...

# %%
for title in goog_list2_titles:
    if title.find('Earnings Call Transcript') >=0:
        print(title)
# Out:
# Alphabet Inc. (GOOG) Q1 2023 Earnings Call Transcript
# Alphabet Inc. (GOOG) Q4 2022 Earnings Call Transcript
# Alphabet Inc. (GOOG) Q3 2022 Earnings Call Transcript

# %%
url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"
headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}
for item in goog_list['data']:
	response = requests.get(url, headers=headers, params={"id": item['id']} )
	filename = item['attributes']['title']
	if filename.find('Earnings Call Transcript') >=0:
		f = open('Google/'+filename, 'w')
		json.dump(response.json(), f)
		f.close()

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

querystring = {"id":"msft","size":"5"}

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())

msft_list = response.json()

# %%
url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"
headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0",
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}
for item in msft_list['data']:
	response = requests.get(url, headers=headers, params={"id": item['id']} )
	filename = item['attributes']['title']
	f = open('Microsoft/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40", "until":'1563503227'}
#Note the new key "until", this denotes the time upto which we need the transcript details

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list3 = response.json()

# %%
transcripts_list3
# Out:
# {'data': [{'id': '4275849',
#    'type': 'earningsSlide',
#    'attributes': {'publishOn': '2019-07-18T16:18:28-04:00',
#     'isLockedPro': False,
#     'commentCount': 16,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Microsoft Corporation 2019 Q4 - Results - Earnings Call Slides',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '568658', 'type': 'tag'}]}},
#    'links': {'self': '/article/4275849-microsoft-corporation-2019-q4-results-earnings-call-slides'}},
#   {'id': '4268292',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2019-06-04T16:38:05-04:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
# ...

# %%
import pandas as pd

transcripts_list3_idtitle = []

for item in transcripts_list3['data']:
    transcripts_list3_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list3_df = pd.DataFrame(transcripts_list3_idtitle)

# %%
transcripts_list3_df
# Out:
#          id                                              Title
# 0   4275849  Microsoft Corporation 2019 Q4 - Results - Earn...
# 1   4268292  Microsoft Corporation (MSFT) Management presen...
# 2   4261782  Nuance Communications, Inc. (NUAN) CEO Mark Be...
# 3   4256516  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 4   4239295  Nuance Communications, Inc (NUAN) CEO Mark Ben...
# 5   4236893  Microsoft Corp (MSFT) CEO Satya Nadella on Q2 ...
# 6   4236837  Microsoft Corporation 2019 Q2 - Results - Earn...
# 7   4232864  Nuance Communications (NUAN) Presents At 37th ...
# 8   4226532  Microsoft Corp. (MSFT) Presents at Barclays Gl...
# 9   4226312  Microsoft Corporation (MSFT) Management Hosts ...
# 10  4225251  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 11  4224913  Microsoft Corp. (MSFT) Presents at Credit Suis...
# 12  4223399  Nuance Communications, Inc (NUAN) CEO Mark Ben...
# 13  4223356  Nuance Communications, Inc. 2018 Q4 - Results ...
# ...

# %%
transcripts_useful3 = transcripts_list3_df.loc[transcripts_list3_df['Title'].str.find('Earnings Call Transcript')>=0]
transcripts_useful3 = transcripts_useful3.loc[transcripts_list3_df['Title'].str.find('MSFT')>=0]

# %%
transcripts_useful3
# Out:
#          id                                              Title
# 3   4256516  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 5   4236893  Microsoft Corp (MSFT) CEO Satya Nadella on Q2 ...
# 15  4214102  Microsoft (MSFT) Q1 2019 Results - Earnings Ca...
# 19  4188569  Microsoft Corporation (MSFT) CEO Satya Nadella...
# 24  4166696  Microsoft (MSFT) Q3 2018 Results - Earnings Ca...
# 26  4141999  Microsoft's (MSFT) CEO Satya Nadella on Q2 201...
# 32  4117127  Microsoft (MSFT) Q1 2018 Results - Earnings Ca...
# 35  4089278  Microsoft's (MSFT) CEO Satya Nadella on Q4 201...
# 39  4066498  Microsoft (MSFT) Q3 2017 Results - Earnings Ca...

# %%
import json

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

for ind in transcripts_useful3.index:
	response = requests.get(url, headers=headers, params={"id": transcripts_useful3['id'][ind]} )
	filename = transcripts_useful3['Title'][ind]
	f = open(company_name+'/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40", "until":'1493344651'}
#Note the new key "until", this denotes the time upto which we need the transcript details

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list4 = response.json()

# %%
transcripts_list4
# Out:
# {'data': [{'id': '4043588',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2017-02-07T19:49:38-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications (NUAN) Q1 2017 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/4043588-nuance-communications-nuan-q1-2017-results-earnings-call-transcript'}},
#   {'id': '4040408',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2017-01-27T00:30:00-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
# ...

# %%
import pandas as pd

transcripts_list4_idtitle = []

for item in transcripts_list4['data']:
    transcripts_list4_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list4_df = pd.DataFrame(transcripts_list4_idtitle)

# %%
transcripts_useful4 = transcripts_list4_df.loc[transcripts_list4_df['Title'].str.find('Earnings Call Transcript')>=0]
transcripts_useful4 = transcripts_useful4.loc[transcripts_list4_df['Title'].str.find('MSFT')>=0]

# %%
transcripts_useful4
# Out:
#          id                                              Title
# 1   4040408  Microsoft (MSFT) Q2 2017 Results - Earnings Ca...
# 7   4013728  Microsoft's (MSFT) CEO Satya Nadella on Q1 201...
# 10  3989628  Microsoft (MSFT) Q4 2016 Results - Earnings Ca...
# 17  3967201  Microsoft (MSFT) Q3 2016 Results - Earnings Ca...
# 21  3846116  Microsoft (MSFT) Q2 2016 Results - Earnings Ca...
# 29  3596736  Microsoft (MSFT) Q1 2016 Results - Earnings Ca...
# 37  3344205  Microsoft (MSFT) Q4 2015 Results - Earnings Ca...

# %%
import json

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

for ind in transcripts_useful4.index:
	response = requests.get(url, headers=headers, params={"id": transcripts_useful4['id'][ind]} )
	filename = transcripts_useful4['Title'][ind]
	f = open(company_name+'/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()

# %%
f = open('Microsoft/Microsoft Corporation (MSFT) Q4 2023 Earnings Call Transcript')
data = json.load(f)
f.close()

# %%
data
# Out:
# {'data': {'id': '4619767',
#   'type': 'fullArticle',
#   'attributes': {'publishOn': '2023-07-25T21:56:09-04:00',
#    'isLockedPro': False,
#    'commentCount': 0,
#    'gettyImageUrl': None,
#    'videoPreviewUrl': None,
#    'themes': {'sa-transcripts': {'id': 96991,
#      'slug': 'sa-transcripts',
#      'kind': 'common',
#      'non_theme': True},
#     'msft': {'id': 575, 'slug': 'msft', 'kind': 'common', 'non_theme': True},
#     'transcripts': {'id': 49,
#      'slug': 'transcripts',
#      'kind': 'general',
#      'path': '/earnings/earnings-call-transcripts',
#      'title': 'Transcripts'},
#     'has-audio': {'id': 586376, 'slug': 'has-audio', 'kind': 'general'},
#     'us': {'id': 326, 'slug': 'us', 'kind': 'common', 'non_theme': True},
#     'information-technology': {'id': 45,
#      'slug': 'information-technology',
#      'kind': 'sector',
#      'path': '/stock-ideas/technology',
#      'title': 'Tech\xa0',
#      'sasource': 'theme_breadcrumb'}},
# ...

# %%
import requests
import pandas as pd

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40", "until":'1431036093'}
#Note the new key "until", this denotes the time upto which we need the transcript details

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list5 = response.json()

transcripts_list5_idtitle = []

for item in transcripts_list5['data']:
    transcripts_list5_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list5_df = pd.DataFrame(transcripts_list5_idtitle)
transcripts_useful5 = transcripts_list5_df.loc[transcripts_list5_df['Title'].str.find('Earnings Call Transcript')>=0]
transcripts_useful5 = transcripts_useful5.loc[transcripts_list5_df['Title'].str.find('MSFT')>=0]
transcripts_useful5
# Out:
#          id                                              Title
# 2   3098136  Microsoft's (MSFT) CEO Satya Nadella on Q3 201...
# 9   2852026  Microsoft's (MSFT) CEO Satya Nadella on Q2 201...
# 19  2592085  Microsoft's (MSFT) CEO Satya Nadella on Q1 201...
# 25  2331775  Microsoft's (MSFT) CEO Satya Nadella on Q4 201...

# %%
import json

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

headers = {
	"X-RapidAPI-Key": "9ac6464e16mshf4a9ec07bba44ebp102253jsn7a211cc553f0", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

for ind in transcripts_useful5.index:
	response = requests.get(url, headers=headers, params={"id": transcripts_useful5['id'][ind]} )
	filename = transcripts_useful5['Title'][ind]
	f = open(company_name+'/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()

# %%
transcripts_list5
# Out:
# {'data': [{'id': '3155946',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2015-05-07T16:55:00-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications (NUAN) Q2 2015 Results - Earnings Call Webcast',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/3155946-nuance-communications-nuan-q2-2015-results-earnings-call-webcast'}},
#   {'id': '3126536',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2015-05-01T00:04:05-04:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
# ...

# %%
import requests
import pandas as pd

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40", "until":'1386192963'}
#Note the new key "until", this denotes the time upto which we need the transcript details

headers = {
	"X-RapidAPI-Key": "89e860e7afmshefb632be272ca2fp1d4159jsn5debf3d824af", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list6 = response.json()

transcripts_list6_idtitle = []

for item in transcripts_list6['data']:
    transcripts_list6_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list6_df = pd.DataFrame(transcripts_list6_idtitle)
transcripts_useful6 = transcripts_list6_df.loc[transcripts_list6_df['Title'].str.find('Earnings Call Transcript')>=0]
transcripts_useful6 = transcripts_useful6.loc[transcripts_list6_df['Title'].str.find('MSFT')>=0]
transcripts_useful6
# Out:
#          id                                              Title
# 15  1557202  Microsoft Corporation (MSFT) Management Discus...

# %%
for ind in transcripts_list6_df.index:
    print(transcripts_list6_df['Title'][ind], end='\n')
# Out:
# Nuance Communications CEO Discusses F4Q 2013 Results - Earnings Call Transcript
# Nuance Communications, Inc. Discusses Q4 2013 Results (Webcast)
# Microsoft's CEO Hosts Annual Shareholder Meeting Conference (Transcript)
# LinkedIn's CEO Discusses Q3 2013 Results - Earnings Call Transcript
# LinkedIn Discusses Q3 2013 Results (Webcast)
# Microsoft's CEO Discusses F1Q 2014 Results - Earnings Call Transcript
# Microsoft Corporation Discusses Q1 2014 Results (Webcast)
# Microsoft's CEO Hosts Financial Analyst Meeting (Transcript)
# Microsoft Corporation's Management Presents at Citi Global Technology Conference (Transcript)
# Microsoft Corporation, Nokia Corporation - M&A Call
# Microsoft to acquire Nokia's Devices & Services business - Corporate Conference Call (Webcast)
# Nuance's CEO Discusses F3Q 2013 Results - Earnings Call Transcript
# Nuance Communications Inc. (NUAN) Management Discusses Q3 2013 Results (Webcast)
# ...

# %%
transcripts_useful6.loc[15]['Title']
# Out:
# 'Microsoft Corporation (MSFT) Management Discusses F4Q 2013 Results - Earnings Call Transcript'

# %%
import json

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/get-details"

headers = {
	"X-RapidAPI-Key": "89e860e7afmshefb632be272ca2fp1d4159jsn5debf3d824af", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

for ind in transcripts_useful6.index:
	response = requests.get(url, headers=headers, params={"id": transcripts_useful6['id'][ind]} )
	filename = transcripts_useful6['Title'][ind]
	f = open(company_name+'/'+filename, 'w')
	json.dump(response.json(), f)
	f.close()

# %%
transcripts_list6
# Out:
# {'data': [{'id': '1862521',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2013-11-25T22:16:05-05:00',
#     'isLockedPro': False,
#     'commentCount': 0,
#     'gettyImageUrl': None,
#     'videoPreviewUrl': None,
#     'themes': {},
#     'title': 'Nuance Communications CEO Discusses F4Q 2013 Results - Earnings Call Transcript',
#     'isPaywalled': False},
#    'relationships': {'author': {'data': {'id': '44211', 'type': 'author'}},
#     'sentiments': {'data': []},
#     'primaryTickers': {'data': [{'id': '575', 'type': 'tag'}]},
#     'secondaryTickers': {'data': []},
#     'otherTags': {'data': [{'id': '49', 'type': 'tag'}]}},
#    'links': {'self': '/article/1862521-nuance-communications-ceo-discusses-f4q-2013-results-earnings-call-transcript'}},
#   {'id': '1861171',
#    'type': 'transcript',
#    'attributes': {'publishOn': '2013-11-25T16:55:00-05:00',
#     'isLockedPro': False,
#     'commentCount': 1,
#     'gettyImageUrl': None,
# ...

# %%
import requests
import pandas as pd

url = "https://seeking-alpha.p.rapidapi.com/transcripts/v2/list"

# Change company_name and symbol according to the company you are interested in
company_name = 'Microsoft'
symbol = 'msft'

#Size controls the number of transcript details returned (not all of them are earnings call transcripts), max size is 40
querystring = {"id":symbol ,"size":"40", "until":'1320367737'}
#Note the new key "until", this denotes the time upto which we need the transcript details

headers = {
	"X-RapidAPI-Key": "89e860e7afmshefb632be272ca2fp1d4159jsn5debf3d824af", #enter your key between the double quotes here
	"X-RapidAPI-Host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)


transcripts_list7 = response.json()

transcripts_list7_idtitle = []

for item in transcripts_list7['data']:
    transcripts_list7_idtitle.append({'id': item['id'], 'Title': item['attributes']['title']})

transcripts_list7_df = pd.DataFrame(transcripts_list7_idtitle)
transcripts_useful7 = transcripts_list7_df.loc[transcripts_list7_df['Title'].str.find('Earnings Call Transcript')>=0]
transcripts_useful7 = transcripts_useful7.loc[transcripts_list7_df['Title'].str.find('MSFT')>=0]
transcripts_useful7
# Out:
# Empty DataFrame
# Columns: [id, Title]
# Index: []

# %%
transcripts_list7_df
# Out:
#         id                                              Title
# 0   301037  Microsoft Management Discusses Q1 2012 Results...
# 1   286177  Nuance Communications' CEO Discusses Q3 2011 R...
# 2   284921  LinkedIn CEO Discusses Q2 2011 Results - Earni...
# 3   281020  Microsoft Management Discusses Q4 2011 Results...
# 4   269188  Nuance Communications' CEO Discusses Q2 2011 R...
# 5   269182   Microsoft to Acquire Skype Press Conference Call
# 6   266457  Microsoft Management Discusses Q3 2011 Results...
# 7   251900  Nuance Communications' CEO Discusses F1Q11 Res...
# 8   249249  Microsoft Management Discusses Q2 2011 Results...
# 9   238195  Nuance CEO Discusses Q4 2010 Results - Earning...
# 10  233449  Transcend Services Q3 2010 CEO Discusses Q3 20...
# 11  233154  Microsoft Management Discusses F1Q11 Results -...
# 12  219661  Nuance Communications, Inc. F3Q10 (06/30/10) E...
# 13  217780  Transcend Services, Inc. Q2 2010 Earnings Call...
# ...
